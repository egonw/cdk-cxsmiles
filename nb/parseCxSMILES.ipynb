# %% [markdown]
# **Install the dependencies**

# %%
# !apt install maven openjdk-11-jdk

# %%
# !pip install pybacting

# %% [markdown]
# **Load the CDK library via pybacting**

# %%
from pybacting import cdk
from scyjava import to_python as j2p
import IPython

# %% [markdown]
# **Parse and visualize the CxSMILES**

# %%
cxmol = cdk.fromSMILES("[H]C\\C=C\\CC(=O)O |Sg:n:1:x:ht,Sg:n:4:y:ht|")
svg = j2p(cdk.asSVG(cxmol))
display(IPython.display.SVG(svg))
